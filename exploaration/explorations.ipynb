# %% [markdown]
# # Exploration

# %%
from backend.constants import DATA_PATH


md_data = DATA_PATH / "data storytelling.md"

# %%
from markdown import markdown
from bs4 import BeautifulSoup

with open(md_data, "r", encoding= "utf-8") as file:
    md_text = file.read() 

html_text = markdown(md_text)
soup = BeautifulSoup(markup=html_text, features="html.parser")

print(soup.get_text())

# %%
import requests


url = "http://localhost:7071/rag/query"

res = requests.post(url, json={"prompt": "What is python"})

print(f"STATUS: {res.status_code}")
print(f"TEXT: {res.text}")

# %%
import requests
from dotenv import load_dotenv
import os 

load_dotenv()


url = f"https://rg-chatbot-de24.azurewebsites.net/rag/query?code={os.getenv('FUNCTION_APP_API')}"


response = requests.post(url, json={"prompt": "What is python"})

print(f"STATUS: {response.status_code}")
print(f"TEXT: {response.text}")
# Out:
# STATUS: 200
# TEXT: {"filename":"python intro","filepath":"C:\\Users\\MAER\\Documents\\STI\\dataplattform_maskininlärning_artificiell_intelligens\\Chatbot_de24\\data\\python intro.txt","answer":"Python is a high-level programming language known for its simple and readable syntax, making it easy to learn and use! 🐍 It's open-source, dynamically typed, and boasts a vast library ecosystem that allows for complex applications. You can use Python for data analysis, machine learning, AI, automation, web scraping, and web development. Learning Python can open doors to careers like Data Scientist, Data Engineer, and Web Developer! 🚀"}

# %%
response.json()
# Out:
# {'filename': 'python intro',
#  'filepath': 'C:\\Users\\MAER\\Documents\\STI\\dataplattform_maskininlärning_artificiell_intelligens\\Chatbot_de24\\data\\python intro.txt',
#  'answer': "Python is a high-level programming language known for its simple and readable syntax, making it easy to learn and use! 🐍 It's open-source, dynamically typed, and boasts a vast library ecosystem that allows for complex applications. You can use Python for data analysis, machine learning, AI, automation, web scraping, and web development. Learning Python can open doors to careers like Data Scientist, Data Engineer, and Web Developer! 🚀"}
